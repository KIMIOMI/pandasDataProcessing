# %%
import pandas as pd

# %%
data = pd.read_excel('data.xlsx')
data
# Out:
#                                                     이름  \
# 0                                         [Lv.0] 제시 카드
# 1                                      [Lv.1] 하샤는 도적이다
# 2    [Lv.2] 어머니를 잃고 아버지와 도적 생활을 하는 하샤의 복면 아래 얼굴은 누구...
# 3                [Lv.1] ’대장장이’이지만 재능이 없는 그리니는 기타로 향한다.
# 4      [Lv.2] 에카에서 태어난 여성이라는 정보만 알려진 하샤는 도적이 아닐 수도...?
# ..                                                 ...
# 592  [Lv.9,072,081] 티나는 심굴문파 본부에 도움 요청을 보내고 빠르게 라자푸...
# 593  [Lv.2,223] 죽은 이들의 강화력이 자신에게 오는 상황을 받아들이지 못한 쿠흐...
# 594  [Lv.8,665,889] 시리우스의 핵이 지구에 출현한 것 또한 운명으로 여긴 염...
# 595  [Lv.8,665,889] 시리우스의 핵이 태양의 자리에 위치하게 되면서 모든 것들...
# 596  [Lv.102] 흑백쌍귀는 풍산에서 무예를 수련하다, 키워주던 노부부가 살해당한 직...
#
#                                                     주소               작성자  \
# 0    https://ageofzen.notion.site/Lv-0-36d0674d1e97...       히로 GM | AOZ
# 1    https://ageofzen.notion.site/Lv-1-33b9016ac6cc...       히로 GM | AOZ
# 2    https://ageofzen.notion.site/Lv-2-10c4c06877ed...  addfsdafsdafsdaf
# 3    https://ageofzen.notion.site/Lv-1-db613ff05da6...               그리니
# 4    https://ageofzen.notion.site/Lv-2-29c4dad3fdcd...             Hwany
# ..                                                 ...               ...
# 592  https://www.notion.so/ageofzen/Lv-9-072-081-3a...        John Jeong
# 593  https://www.notion.so/ageofzen/Lv-2-223--ca8e1...           Chungha
# 594  https://www.notion.so/ageofzen/Lv-8-665-889--e...              크레파스
# 595  https://www.notion.so/ageofzen/Lv-8-665-889-7-...               그리니
# 596  https://www.notion.so/ageofzen/Lv-102-a38a07b1...       히로 GM | AOZ
#
#                                                  이전 카드  \
# 0                                                  NaN
# 1    https://www.notion.so/Lv-0-36d0674d1e974e878e9...
# 2    https://www.notion.so/Lv-1-33b9016ac6cc4425ae6...
# 3    https://www.notion.so/Lv-0-36d0674d1e974e878e9...
# 4    https://www.notion.so/Lv-1-33b9016ac6cc4425ae6...
# ..                                                 ...
# 592  https://www.notion.so/Lv-413-65320831adc1480cb...
# 593  https://www.notion.so/Lv-101-9cd6244452bc457bb...
# 594  https://www.notion.so/Lv-8-665-888-9f163dd824e...
# 595  https://www.notion.so/Lv-8-665-888-9f163dd824e...
# 596  https://www.notion.so/Lv-101-d66c5ab90e594921a...
#
#                                                  주인공 🏃                  일시  \
# 0    그리니, 그리니A, 리엘, 식이, 아마리테, 우자, 월하, 월하A, 윈디, 유나, ... 2022-03-18 17:13:00
# 1                           하샤, 하샤A, 하샤B, 하샤C(비루), 하샤K 2022-03-25 10:52:00
# 2                                              하샤, 하샤A 2022-04-01 00:06:00
# 3                                            그리니, 그리니A 2022-04-01 00:14:00
# 4                                              하샤, 하샤B 2022-04-01 00:18:00
# ..                                                 ...                 ...
# 592                                     루나, 유다, 티나, 하린 2022-04-24 23:13:00
# 593                                           그리니, 쿠흐카 2022-04-24 23:27:00
# 594                                                 염라 2022-04-24 23:48:00
# 595                                                NaN 2022-04-24 23:52:00
# 596                                         흑백쌍귀(흑노백노) 2022-05-25 15:58:00
#
#                            배경 🏜                              아이템/능력 ⚔️  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                     복면
# 3    고가, 기타, 망맥, 에카, 춤추는 호수(무호)                                    NaN
# 4                            에카                                    NaN
# ..                          ...                                    ...
# 592                      운명의 습지  _x0008_영혼 유령체, 라자푸트리, 시리우스의 핵, 타이거 소드
# 593                         NaN                       111개의 구슬, 단검, 비약
# 594                       마하드비파                                시리우스의 핵
# 595                       마하드비파                                시리우스의 핵
# 596                    천마신교, 풍산                                    NaN
#
#                              인물 🪆    장소 🏕  직업 🧥          키워드
# 0                             NaN     NaN   NaN          NaN
# 1                             NaN     NaN    도적          NaN
# 2                             아버지     NaN    도적          NaN
# 3                             NaN     NaN  대장장이          NaN
# 4                             NaN      평원    도적          NaN
# ..                            ...     ...   ...          ...
# 592  그리니, 아인드라, 악마 젠콩, 제니, 청묘, 하샤  가이아의 늪   NaN   영혼, 전투, 희망
# 593                      쿠흐카의 아버지     NaN   NaN      강화력, 반군
# 594                           NaN     NaN   NaN  제 2의 태양, 현신
# 595                        빌런, 영웅     NaN   NaN          제자리
# 596                            천마     NaN   NaN          쌍둥이
#
# [597 rows x 12 columns]

# %%
원본이전카드 = data['이전 카드']
원본현재카드 = data['주소']
원본작성자 = data['작성자']

# %%
이전카드_개수 =[]
이전카드_앞주소제거=[]
제거값 = 'https://www.notion.so/'
for i in 원본이전카드:
    if type(i) == str:
        i = i.replace(제거값,'')
        주소 = i.split()
        a = len(주소)
    else:
        a = ''
        주소 = ''
    이전카드_개수.append(a)
    이전카드_앞주소제거.append(주소)

# %%
현재카드_앞주소제거=[]
제거값1 = 'https://ageofzen.notion.site/'
제거값2 = 'https://www.notion.so/ageofzen/'
for i in 원본현재카드:
    if type(i) == str:
        주소 = i.replace(제거값1,'').replace(제거값2, '')
    else:
        주소 = ''
    현재카드_앞주소제거.append(주소)

# %%
index = list(range(0,len(현재카드_앞주소제거)))
a = pd.Series(현재카드_앞주소제거)
b = pd.Series(이전카드_앞주소제거)
c = pd.Series(원본작성자)


new_data = pd.DataFrame(a, index, ['현재카드'])
new_data['이전카드'] = b
new_data['원본작성자'] = c

new_data
# Out:
#                                                   현재카드  \
# 0                Lv-0-36d0674d1e974e878e932d9152a6fefc
# 1                Lv-1-33b9016ac6cc4425ae650f96583143db
# 2                Lv-2-10c4c06877ed4219bb663fea911dd11e
# 3                Lv-1-db613ff05da64713b7914418b62a3239
# 4                Lv-2-29c4dad3fdcd4fc5a5d78ba46eb6f9c2
# ..                                                 ...
# 592      Lv-9-072-081-3a9abec4fed343788a5626f3474ef097
# 593         Lv-2-223--ca8e1a22bb02475fb326157298144689
# 594     Lv-8-665-889--e259033965864c49bd636a94e48a5301
# 595  Lv-8-665-889-7-777-8-888-1db803109d514baabcdc5...
# 596            Lv-102-a38a07b1039b4fe0bcae5302467876e2
#
#                                                   이전카드             원본작성자
# 0                                                            히로 GM | AOZ
# 1              [Lv-0-36d0674d1e974e878e932d9152a6fefc]       히로 GM | AOZ
# 2              [Lv-1-33b9016ac6cc4425ae650f96583143db]  addfsdafsdafsdaf
# 3              [Lv-0-36d0674d1e974e878e932d9152a6fefc]               그리니
# 4    [Lv-1-33b9016ac6cc4425ae650f96583143db, Lv-0-3...             Hwany
# ..                                                 ...               ...
# 592  [Lv-413-65320831adc1480cb38f7b0394699e75, Lv-5...        John Jeong
# 593  [Lv-101-9cd6244452bc457bb2473131e7545c70, Lv-1...           Chungha
# 594    [Lv-8-665-888-9f163dd824e44250bbfcf3cfe78c5bcb]              크레파스
# 595    [Lv-8-665-888-9f163dd824e44250bbfcf3cfe78c5bcb]               그리니
# 596          [Lv-101-d66c5ab90e594921a363ef7f6b2eb20f]       히로 GM | AOZ
#
# [597 rows x 3 columns]

# %%
new_data['모든이전카드'] = ''
new_data['모든기여자'] = ''
모든이전카드_개수 = []
모든이전카드 = []
에러카드 = []
모든기여자 = []

num = 0
for i in new_data.index:
    이전카드들 = new_data['이전카드'][i]
    작성자 = new_data['원본작성자'][i]
    모든기여자 = []
    모든기여자.append(작성자)

    if type(이전카드들) == list:
        모든카드 = 이전카드들.copy()
    else:
        모든카드 = ''

    if len(이전카드들) == 0:
        pass
    else:
        for 이전카드 in 이전카드들:
            쿼리결과 = new_data.query(f"현재카드 == '{이전카드}'")
            쿼리카드 = 쿼리결과['모든이전카드'].tolist()
            쿼리작성자 = 쿼리결과['원본작성자'].tolist()
            if len(쿼리카드) != 0:
                쿼리카드 = 쿼리카드[0]
                if len(쿼리작성자) != 0:
                    쿼리작성자 = 쿼리작성자[0]
                else:
                    print(f"{i}번째 카드의 {이전카드} 작성자 오류")
                for 쿼리리스트 in 쿼리카드:
                    if 쿼리리스트 != '':
                        모든카드.append(쿼리리스트)
                모든기여자.append(쿼리작성자)
            else:
                print(f'{i}번째 카드의 {이전카드}에서 쿼리 에러 발생')
                에러카드.append(이전카드)

    모든카드중복제거 = set(모든카드)
    모든카드 = list(모든카드중복제거)
    모든기여자 = list(set(모든기여자))

    new_data['모든이전카드'][i] = 모든카드
    new_data['모든기여자'][i] = 모든기여자
new_data['모든이전카드 개수'] = new_data['모든이전카드'].str.len()
에러카드 = list(set(에러카드))
new_data['모든기여자 수'] = new_data['모든기여자'].str.len()
# Out:
# C:\Users\pluse\AppData\Local\Temp\ipykernel_27080\1695757747.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['모든이전카드'][i] = 모든카드
# C:\Users\pluse\AppData\Local\Temp\ipykernel_27080\1695757747.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['모든기여자'][i] = 모든기여자
# 151번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 157번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 188번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 213번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 235번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 264번째 카드의 d3e1be3b659f446a845a989c89605f98에서 쿼리 에러 발생
# 279번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 288번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 288번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 288번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 288번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 288번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 288번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 300번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 300번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 300번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 300번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 300번째 카드의 cbc79f66e81d4e358bf78b5600f066f0에서 쿼리 에러 발생
# 300번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 302번째 카드의 d6a59290572a42eab5f6dde4a050cc5c에서 쿼리 에러 발생
# 306번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 306번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 306번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 306번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 306번째 카드의 f0b42d6a96eb4602977c32d6415fc6b7에서 쿼리 에러 발생
# 306번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 310번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 310번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 310번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 310번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 310번째 카드의 dbd865d8595244b080a76edece741265에서 쿼리 에러 발생
# 310번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 311번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 311번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 311번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 311번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 311번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 311번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 314번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 314번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 314번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 314번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 314번째 카드의 879d55793f1442bca6e0528a2a2e8827에서 쿼리 에러 발생
# 314번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 317번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 317번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 317번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 317번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 317번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 317번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 318번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 318번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 318번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 318번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 318번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 318번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 323번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 323번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 323번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 323번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 323번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 323번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 331번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 331번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 331번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 331번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 331번째 카드의 d6a59290572a42eab5f6dde4a050cc5c에서 쿼리 에러 발생
# 331번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 333번째 카드의 d6a59290572a42eab5f6dde4a050cc5c에서 쿼리 에러 발생
# 337번째 카드의 f0b42d6a96eb4602977c32d6415fc6b7에서 쿼리 에러 발생
# 339번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 339번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 339번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 339번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 339번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 339번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 345번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 345번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 345번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 345번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 345번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 345번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 346번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 346번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 346번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 346번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 346번째 카드의 cbc79f66e81d4e358bf78b5600f066f0에서 쿼리 에러 발생
# 346번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 349번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 349번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 349번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 349번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 349번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 349번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 353번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 353번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 353번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 353번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 353번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 353번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 356번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 356번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 356번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 356번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 356번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 356번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 362번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 362번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 362번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 362번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 362번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 362번째 카드의 cbc79f66e81d4e358bf78b5600f066f0에서 쿼리 에러 발생
# 362번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 365번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 365번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 365번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 365번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 365번째 카드의 d6a59290572a42eab5f6dde4a050cc5c에서 쿼리 에러 발생
# 365번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 370번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 370번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 370번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 370번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 370번째 카드의 5652b1d3668141678cac15ec25559274에서 쿼리 에러 발생
# 370번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 380번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 380번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 380번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 380번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 380번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 380번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 383번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 383번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 383번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 383번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 383번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 383번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 387번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 387번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 387번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 387번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 387번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 387번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 389번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 389번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 389번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 389번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 389번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 389번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 393번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 393번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 393번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 393번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 393번째 카드의 d6a59290572a42eab5f6dde4a050cc5c에서 쿼리 에러 발생
# 393번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 397번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 397번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 397번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 397번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 397번째 카드의 dbd865d8595244b080a76edece741265에서 쿼리 에러 발생
# 397번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 406번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 406번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 406번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 406번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 406번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 406번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 413번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 413번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 413번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 413번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 413번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 413번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 416번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 416번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 416번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 416번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 416번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 416번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 424번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 424번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 424번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 424번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 424번째 카드의 dbd865d8595244b080a76edece741265에서 쿼리 에러 발생
# 424번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 438번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 438번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 438번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 438번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 438번째 카드의 879d55793f1442bca6e0528a2a2e8827에서 쿼리 에러 발생
# 438번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 452번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 452번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 452번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 452번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 452번째 카드의 879d55793f1442bca6e0528a2a2e8827에서 쿼리 에러 발생
# 452번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 493번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 493번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 493번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 493번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 493번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 493번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 494번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 494번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 494번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 494번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 494번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 494번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 500번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 500번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 500번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 500번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 500번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 500번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 505번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 505번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 505번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 505번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 505번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 505번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 506번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 506번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 506번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 506번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 506번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 506번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 508번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 508번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 508번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 508번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 508번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 508번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 509번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 509번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 509번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 509번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 509번째 카드의 a0c35d5c61054dc6bba101eab034ce11에서 쿼리 에러 발생
# 509번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 510번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 510번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 510번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 510번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 510번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 510번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 512번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 512번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 512번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 512번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 512번째 카드의 17a031504c5946a4a197caf98bb5e3ae에서 쿼리 에러 발생
# 512번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 513번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 513번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 513번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 513번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 513번째 카드의 cbc79f66e81d4e358bf78b5600f066f0에서 쿼리 에러 발생
# 513번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 517번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 517번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 517번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 517번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 517번째 카드의 f0b42d6a96eb4602977c32d6415fc6b7에서 쿼리 에러 발생
# 517번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 522번째 카드의 Lv-20-be09fd9c5a9d4e6a97ff65fbfa4f3820[X2]에서 쿼리 에러 발생
# 522번째 카드의 살인자에서 쿼리 에러 발생
# 522번째 카드의 그리니에서 쿼리 에러 발생
# 522번째 카드의 카드에서 쿼리 에러 발생
# 534번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 534번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 534번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 534번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 534번째 카드의 122f820ac63e42f197fe167694ca293b에서 쿼리 에러 발생
# 534번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 539번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 539번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 539번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 539번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 539번째 카드의 dbd865d8595244b080a76edece741265에서 쿼리 에러 발생
# 539번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 544번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 544번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 544번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 544번째 카드의 12a7f6af06d24c3a81484d3cd6d42843에서 쿼리 에러 발생
# 544번째 카드의 e35dc623cb0444ebb150bf1a1fc85f3d에서 쿼리 에러 발생
# 544번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 547번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 547번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 547번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 547번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 547번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 547번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 564번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 564번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 564번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 564번째 카드의 2a44e3e5f39b4ec1b2e91444fed042f1에서 쿼리 에러 발생
# 564번째 카드의 c35e54903be54d7da669c66f16055bd5에서 쿼리 에러 발생
# 564번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생
# 565번째 카드의 942e82a6d47a4bc392784791c6b48b33에서 쿼리 에러 발생
# 565번째 카드의 6e145688d05d4a319243c40da7402906에서 쿼리 에러 발생
# 565번째 카드의 d6421f403f9b41ef95f7bf61d62803ba에서 쿼리 에러 발생
# 565번째 카드의 a0c3ebca1b134a6b93f2465d053c1d87에서 쿼리 에러 발생
# 565번째 카드의 879d55793f1442bca6e0528a2a2e8827에서 쿼리 에러 발생
# 565번째 카드의 8c6373c9b95e4b1d916275f21becefd8에서 쿼리 에러 발생

# %%
쿼리카드 = new_data.query("현재카드 == 'd3e1be3b659f446a845a989c89605f98'")['모든이전카드'].tolist()
print(len(쿼리카드))
# Out:
# 0

# %%
new_data['현재카드'][133]
# Out:
# 'Lv-121-1-d172f02b063644a8b04379a039bc1430'

# %%
에러카드
# Out:
# ['17a031504c5946a4a197caf98bb5e3ae',
#  '2a44e3e5f39b4ec1b2e91444fed042f1',
#  'd6a59290572a42eab5f6dde4a050cc5c',
#  'a0c3ebca1b134a6b93f2465d053c1d87',
#  '5652b1d3668141678cac15ec25559274',
#  'd6421f403f9b41ef95f7bf61d62803ba',
#  '879d55793f1442bca6e0528a2a2e8827',
#  '122f820ac63e42f197fe167694ca293b',
#  'a0c35d5c61054dc6bba101eab034ce11',
#  'd3e1be3b659f446a845a989c89605f98',
#  'e35dc623cb0444ebb150bf1a1fc85f3d',
#  '그리니',
#  'dbd865d8595244b080a76edece741265',
#  '살인자',
#  'c35e54903be54d7da669c66f16055bd5',
#  '카드',
#  'cbc79f66e81d4e358bf78b5600f066f0',
#  '6e145688d05d4a319243c40da7402906',
#  'Lv-20-be09fd9c5a9d4e6a97ff65fbfa4f3820[X2]',
#  '942e82a6d47a4bc392784791c6b48b33',
#  'f0b42d6a96eb4602977c32d6415fc6b7',
#  '8c6373c9b95e4b1d916275f21becefd8',
#  '12a7f6af06d24c3a81484d3cd6d42843']

# %%
new_data.to_excel('result.xlsx')

# %%
new_data['모든이전카드'][282]
# Out:
# ['Lv-9-859eb38ff3074beb9cec38f15238ba2b',
#  'Lv-3-588-4-7078c9eb8749468793bc4d6352e38a0b',
#  'Lv-1-9dcb92c9375d44d69dc660ca12099e28',
#  'Lv-48-299aea606f7d43cf8da97df8ebe86ddf',
#  'Lv-8-3-8b29291e73ec4c03b1cc18a9d85a928e',
#  'Lv-3-091-840044d39322409d8f5036954bce7548',
#  'Lv-1-044-0c903f0efb3a4f92a33071ce70b0f458',
#  'Lv-5-cb6bc245b1c74ae3b84174516b942697',
#  'Lv-12-91d1ddf971584ceab6f0ce49eced4e15',
#  'Lv-4-1-593481df692b4a1ebe32f7ff46313f10',
